# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm=ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response=llm.invoke("What is the ultimate advantage of using an Agentic AI architecture? , make sure the answer is short within 2-3 lines")
print(response.text)
